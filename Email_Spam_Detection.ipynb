# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_extraction.text import CountVectorizer
import streamlit as st
from sklearn.naive_bayes import MultinomialNB , BernoulliNB

# %%
# !pip install streamlit
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 50.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.4/11.4 MB 58.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cfb357b8-4df7-4ff1-a035-0983be93a3a9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cfb357b8-4df7-4ff1-a035-0983be93a3a9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("spam.csv")

# %%
df.iloc[0]
# Out:
# Category                                                  ham
# Message     Go until jurong point, crazy.. Available only ...
# Name: 0, dtype: object

# %%
df.describe()
# Out:
#        Category                 Message
# count      5572                    5572
# unique        2                    5157
# top         ham  Sorry, I'll call later
# freq       4825                      30

# %%
df.isnull().sum()
# Out:
# Category    0
# Message     0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#      Category                                            Message
# 0         ham  Go until jurong point, crazy.. Available only ...
# 1         ham                      Ok lar... Joking wif u oni...
# 2        spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3         ham  U dun say so early hor... U c already then say...
# 4         ham  Nah I don't think he goes to usf, he lives aro...
# ...       ...                                                ...
# 5567     spam  This is the 2nd time we have tried 2 contact u...
# 5568      ham               Will ü b going to esplanade fr home?
# 5569      ham  Pity, * was in mood for that. So...any other s...
# 5570      ham  The guy did some bitching but I acted like i'd...
# 5571      ham                         Rofl. Its true to its name
#
# [5157 rows x 2 columns]

# %%
df['Category'] = df['Category'].map({'ham': 'Not Spam', 'spam': 'Spam'})
df.head()
# Out:
#    Category                                            Message
# 0  Not Spam  Go until jurong point, crazy.. Available only ...
# 1  Not Spam                      Ok lar... Joking wif u oni...
# 2      Spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3  Not Spam  U dun say so early hor... U c already then say...
# 4  Not Spam  Nah I don't think he goes to usf, he lives aro...

# %%
x = df['Message']
y = df['Category']

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
cv = CountVectorizer(stop_words='english')
feature = cv.fit_transform(x_train)

# %%
model1 = MultinomialNB()
model1.fit(feature,y_train)

model2 = BernoulliNB()
model2.fit(feature,y_train)
# Out:
# BernoulliNB()

# %%
y_pred = model1.predict(cv.transform(x_test))
print(accuracy_score(y_test,y_pred))

y_pred2 = model2.predict(cv.transform(x_test))
print(accuracy_score(y_test,y_pred2))
# Out:
# 0.9865470852017937
# 0.9757847533632287

# %%
message = cv.transform(["you won a lottery. Congrates"]).toarray()
result = model1.predict(message)
print(result)

message = cv.transform(["you won a lottery. Congrates"]).toarray()
result = model2.predict(message)
print(result)
# Out:
# ['Spam']
# ['Not Spam']

# %%
message = cv.transform(["lets watch movie together"]).toarray()
result = model1.predict(message)
print(result)

message = cv.transform(["u won fifa ticket congrates , click here"]).toarray()
result = model1.predict(message)
print(result)

message = cv.transform(["hi , he texted me today"]).toarray()
result = model1.predict(message)
print(result)
# Out:
# ['Not Spam']
# ['Spam']
# ['Not Spam']

# %%
def predict(messages):
  input_message = cv.transform([messages]).toarray()
  result = model1.predict(input_message)
  return result

st.header("SPAM DETECTION")

input_message = st.text_input("Enter your message")

if st.button('Predict'):
  result = predict(input_message)
  st.markdown(result)
# Out:
# 2026-07-03 15:51:17.444 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-03 15:51:17.651
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.12/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
# 2026-07-03 15:51:17.655 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-03 15:51:17.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-03 15:51:17.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-03 15:51:17.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-07-03 15:51:17.669 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
